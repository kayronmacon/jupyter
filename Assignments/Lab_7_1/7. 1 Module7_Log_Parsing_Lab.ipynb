# %% [markdown]
# # Module 7 – Log Parsing Lab
# ## Applying Python to Cybersecurity

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## Task 1 – Load the Dataset

# %%
# Load dataset
df = pd.read_csv('auth_logs.csv')
df.head()

# %% [markdown]
# ## Task 2 – Feature Extraction

# %%
# Count failed logins per user
failed_logins = df[df['event_type'] == 'LOGIN_FAILED']
failed_logins.groupby('user').size()

# %% [markdown]
# ## Task 3 – Rule-Based Detection

# %%
# Convert timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Flag activity between 2AM–4AM
df['hour'] = df['timestamp'].dt.hour
suspicious_hours = df[(df['hour'] >= 2) & (df['hour'] <= 4)]
suspicious_hours.head()

# %% [markdown]
# ## Final Reflection
# Write 1–2 paragraphs summarizing suspicious patterns observed.
