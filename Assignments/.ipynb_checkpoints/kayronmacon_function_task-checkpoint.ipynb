# %% [markdown]
# # 🧩 Function Writing Task – Module 2
# Create a function to summarize a list of numbers.
#
# This notebook is your starting point. Complete the function below to calculate:
# - Total count
# - Average
# - Maximum value
#
# Handle the case where the list is empty by returning zeros or a message.

# %%
# TODO: Define the summarize_data function below
def summarize_data(numbers):
    total = 0
    if len(numbers) > 0:
        for item in numbers:
            total = item + total
            length = len(numbers)
            average = total / length
            stats = (
            f"\n"
            f"Mean: {average}\n"
            f"Sum: {total}\n"
            f"Max: {max(sample_list)}" 
            )
        if length < 10: #print list if not too long
            
            # original formatted list
            list = f"{', '.join(str(n) for n in numbers)}"
            
            #sort numbers
            sorted_numbers = numbers.copy()
            sorted_numbers.sort() 

            # formatted sorted list
            sorted_list = f"Sorted: {', '.join(str(n) for n in numbers)}"

            # result
            result = f"\nLength = {length}\n{list}\n{sorted_list}\n{stats}"
        else:
            result = stats

    else:
        result = "Your list is empty"
    return result
        

    # Your code here

# %%
# Sample list for testing
sample_list = [12, 45, 67, 23, 89]



# Call your function and print the results
result = summarize_data(sample_list)
print("Summary:", result)
# Out:
# Summary:
# Length = 5
# 12, 45, 67, 23, 89
# Sorted: 12, 45, 67, 23, 89
#
# Mean: 47.2
# Sum: 236
# Max: 89

# %%
# Test with an empty list
empty_list = []
result = summarize_data(empty_list)
print("Summary for empty list:", result)
# Out:
# Summary for empty list: Your list is empty

# %% [markdown]
# ### ✅ Reflection
# What did you find challenging or interesting about writing this function?
#
# You may write your answer here or discuss it in your Canvas submission.
